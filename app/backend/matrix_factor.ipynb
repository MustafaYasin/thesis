# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/myasin/Documents/thesis/app/backend/csv_folder/pytorch_pytorch.csv')
df.head()
# Out:
#          username                  name                      email  \
# 0          alexbw        Alex Wiltschko          alex.bw@gmail.com
# 1         iassael         Yannis Assael          iassael@gmail.com
# 2   bshillingford  Brendan Shillingford                        NaN
# 3        hmansell        Howard Mansell         howard@mansells.us
# 4  clementfarabet       Clement Farabet  clement.farabet@gmail.com
#
#    repo_count   company                                         avatar_url  \
# 0          47    Google  https://avatars.githubusercontent.com/u/161935...
# 1          27  DeepMind  https://avatars.githubusercontent.com/u/216211...
# 2          24       NaN  https://avatars.githubusercontent.com/u/232674...
# 3           0  Facebook  https://avatars.githubusercontent.com/u/980875...
# 4          79  @NVIDIA   https://avatars.githubusercontent.com/u/188959...
#
#    hireable            star_time
# 0     False  2016-08-15 18:39:55
# 1      True  2016-08-15 19:14:32
# ...

# %%
df.drop(['username', 'company', 'avatar_url', 'email', 'star_time'], axis=1, inplace=True)
df
# Out:
#                           name  repo_count  hireable
# 0               Alex Wiltschko          47     False
# 1                Yannis Assael          27      True
# 2         Brendan Shillingford          24     False
# 3               Howard Mansell           0     False
# 4              Clement Farabet          79     False
# ..                         ...         ...       ...
# 95              Alexey Romanov          23     False
# 96                 Shiven Mian          14      True
# 97               Matt Mollison          30     False
# 98                JJ Robertson          24     False
# 99  Muhammad Sumon Molla Selim          16     False
#
# [100 rows x 3 columns]

# %%
rc = df.loc[0]['repo_count']
h = df.loc[0]['hireable']
rc * h
# Out:
# 0

# %%
df = df.values()
user_repo_mean = np.mean(df, axis = 1)
Repo_demeaned = df - user_ratings_mean.reshape(-1, 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 df = df.values()
#       2 user_repo_mean = np.mean(df, axis = 1)
#       3 Repo_demeaned = df - user_ratings_mean.reshape(-1, 1)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
from pymongo import MongoClient
client = MongoClient("mongodb+srv://profile:profile@cluster0.vsf5mmw.mongodb.net/?retryWrites=true&w=majority")
print("Connection Successful")
client.close()
# Out:
# Connection Successful

# %%
from pymongo import MongoClient
import pandas as pd
from flask_restful import Resource, reqparse
import json


client = MongoClient("mongodb+srv://profile:profile@cluster0.vsf5mmw.mongodb.net/?retryWrites=true&w=majority")
db = client['profile']

real_user_db = db['real_user']




def check_user_in_DB(input_user):
    # suche user mit id ... 
    existence = real_user_db.find_one({'id': input_user['id']})

    # wenn existiert True, else False
    try:
        len(existence)
        return True
    except:
        return False
    

def add_user_to_db(input_user):

    if check_user_in_DB(input_user):
        done = {'msg': 'user already exists in DB'}
    else:
        real_user_db.insert_one(input_user)
        done = {'msg':'user succesfully added to DB'}
    return done


# for flask route
class Add_user(Resource):

    # incoming arguments
    def post(self):
        partner_feed_generator = reqparse.RequestParser()
        partner_feed_generator.add_argument('id', help='This field cannot be blank', required=True, type=int)
        partner_feed_generator.add_argument('username', help='This field cannot be blank', required=True, type=str)                           
        partner_feed_generator.add_argument('name', help='This field cannot be blank', required=True, type=str)
        partner_feed_generator.add_argument('email', help='This field cannot be blank', required=True, type=str)
        partner_feed_generator.add_argument('repo_count', help='This field cannot be blank', required=True, type=int)
        partner_feed_generator.add_argument('company', help='This field cannot be blank', required=False, type=str)
        partner_feed_generator.add_argument('avatar_url', help='This field cannot be blank', required=False, type=str)
        partner_feed_generator.add_argument('hireable', help='This field cannot be blank', required=False, type=str)
        partner_feed_generator.add_argument('star_time', help='This field cannot be blank', required=False, type=str)


        input_user = partner_feed_generator.parse_args()

        done = add_user_to_db(input_user)
        done = json.dumps(done, indent=4)
        return {'response': done}, 200
